# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../ext_data/loc4.csv")

# %%
x, y = df['lat'].values, df['long'].values

# %%
# plt.scatter(x, y)
# plt.show()
x.dtype
# Out:
# dtype('O')
