# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../ext_data/loc4.csv")

# %%
x, y = df['lat'].values, df['long'].values

# %%
plt.scatter(x, y)
plt.show()

# %%
df[df['lat'] < 55.5]
# Out:
#      Unnamed: 0  Unnamed: 0.1                           raion        lat  \
# 3             3           4.0                       Basmannoe  55.104476
# 49           49          65.0                        Krjukovo  55.099011
# 88           88         126.0          Poselenie Desjonovskoe  55.499571
# 91           91         129.0                  Troickij okrug  55.355771
# 96           96         134.0           Poselenie Shhapovskoe  55.391631
# 97           97         135.0          Poselenie Rjazanovskoe  55.482373
# 99           99         138.0       Poselenie Krasnopahorskoe  55.421496
# 100         100         139.0       Poselenie Novofedorovskoe  55.425640
# 101         101         140.0           Poselenie Voronovskoe  55.323848
# 102         102         141.0            Poselenie Klenovskoe  55.314208
# 103         103         142.0             Poselenie Rogovskoe  55.220038
# 104         104         143.0              Poselenie Kievskij  55.394878
# ...

# %%
df[['raion', 'lat', 'long']].to_csv("../ext_data/loc5.csv")
