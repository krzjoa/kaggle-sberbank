# %%
import numpy as np
import pandas as pd

# %%
# CENTRUM MOSKWY
#LAT = 55.751598 
#LON = 37.618914
# Sprawdzić
LON = 55.751598 
LAT = 37.618914

# %%
df = pd.read_csv("../ext_data/loc.csv")

# %%
YANDEX_URL = "https://geocode-maps.yandex.ru/1.x"
#STATIC = "/?format=json&lang=en_US&geocode="
STATIC = "/?format=json&lang=ru_RU&geocode="

import requests
import json

def geocode(name):
    response = requests.get(YANDEX_URL + STATIC + name)
    parsed_dict = json.loads(response.content)
    try:
        pos =  parsed_dict['response']['GeoObjectCollection']['featureMember'][0]['GeoObject']['Point']['pos']
        lat, lon = [float(item) for item in pos.split()]
        return lat, lon
    except:
        return None, None

# %%
geocode("Nagatinskiy Zaton")
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# (37.700658, 55.685274)

# %%
train = pd.read_csv("../data/train.csv")
raions =  train.sub_area.unique()

# %%
def transform(string):
    if string.endswith("oe"):
        return string[:-2]+"oye"
    else:
        return string

# %%
raions = [transform(r) for r in raions]

# %%
rows = []

for r in raions:
    lat, lon = geocode(r)
    print lat, lon
    rows.append(
        {'raion': r, 'latitude': lat, 'longitude':lon}
    )

df = pd.DataFrame(rows)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# 37.607745 55.894879
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# 37.700658 55.685274
# ...

# %%
#df

# %%
#df2 = pd.read_csv("../ext_data/loc2.csv")

# %%
df = df.fillna(0)

# %%
df[df['latitude'] == 0].to_csv("../ext_data/nans.csv")

# %%
df['latdiff'] = df['latitude'] - LAT

# %%
df['londiff'] = df['longitude'] - LON

# %%
df
# Out:
#       latitude  longitude                            raion    latdiff  \
# 0    37.607745  55.894879                         Bibirevo  -0.011169
# 1    37.700658  55.685274                Nagatinskij Zaton   0.081744
# 2    46.479722  60.964774                   Tekstil'shhiki   8.860808
# 3    37.365828  55.845370                           Mitino  -0.253086
# 4    37.749894  55.104476                       Basmannoye   0.130980
# 5    39.922092  44.270958                  Nizhegorodskoye   2.303178
# 6    23.986428  49.777142                       Sokol'niki -13.632486
# 7    37.529043  55.832515                          Koptevo  -0.089871
# 8    37.398482  55.742610                          Kuncevo  -0.220432
# 9          NaN        NaN                Kosino-Uhtomskoye        NaN
# 10   37.519162  55.872339                Zapadnoe Degunino  -0.099752
# 11   37.539239  55.746274                     Presnenskoye  -0.079675
# ...

# %%
# Podejrzane miejsca
df[abs(df['latdiff']) > 1].to_csv("../ext_data/wrong_dist.csv")

# %%
cleaned = df[(abs(df['latdiff']) < 1) & (abs(df['londiff']) < 1) & (df['latitude'] > 0)]

# %%
x = cleaned.values[:, 0]
y = cleaned.values[:, 1]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)
plt.show()
