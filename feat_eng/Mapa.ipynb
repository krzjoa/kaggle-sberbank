# %%
import numpy as np
import pandas as pd

# %%
# CENTRUM MOSKWY
LAT = 55.751598 
LON = 37.618914
# Sprawdzić
#LON = 55.751598 
#LAT = 37.618914

# %%
df = pd.read_csv("../ext_data/loc.csv")

# %%
YANDEX_URL = "https://geocode-maps.yandex.ru/1.x"
#STATIC = "/?format=json&lang=en_US&geocode="
STATIC = "/?format=json&lang=ru_RU&geocode="

import requests
import json

def geocode(name):
    response = requests.get(YANDEX_URL + STATIC + name)
    parsed_dict = json.loads(response.content)
    try:
        pos =  parsed_dict['response']['GeoObjectCollection']['featureMember'][0]['GeoObject']['Point']['pos']
        lat, lon = [float(item) for item in pos.split()]
        return lat, lon
    except:
        return None, None

# %%
geocode("Nagatinskiy Zaton")
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# (37.700658, 55.685274)

# %%
train = pd.read_csv("../data/train.csv")
raions =  train.sub_area.unique()
len(raions)
# Out:
# 146

# %%
def transform(string):
    if string.endswith("oe"):
        return string[:-2]+"oye"
    else:
        return string

# %%
raions = [transform(r) for r in raions]

# %%
rows = []

for r in raions:
    lat, lon = geocode(r)
    print lat, lon
    rows.append(
        {'raion': r, 'latitude': lat, 'longitude':lon}
    )

df = pd.DataFrame(rows)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# 37.607745 55.894879
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# 37.700658 55.685274
# ...

# %%
#df

# %%
#df2 = pd.read_csv("../ext_data/loc2.csv")

# %%
df = df.fillna(0)

# %%
df[df['latitude'] == 0].to_csv("../ext_data/nans.csv")

# %%
df['latdiff'] = df['latitude'] - LAT

# %%
df['londiff'] = df['longitude'] - LON

# %%
#df

# %%
# Podejrzane miejsca
df[abs(df['latdiff']) > 1].to_csv("../ext_data/wrong_dist.csv")

# %%
cleaned = df[(abs(df['latdiff']) < 1) & (abs(df['londiff']) < 1) & (df['latitude'] > 0)]

# %%
x = cleaned.values[:, 0]
y = cleaned.values[:, 1]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)
plt.show()

# %%
# Bazowe
base = pd.read_csv("../ext_data/loc2.csv")

# %%
# Porawione nany
nans = pd.read_csv("../ext_data/nans.csv")

# %%
val = nans[nans.columns[6]].str.split(",").apply(pd.Series).rename(columns={0:"lat", 1:"long"})
nans = nans.join(val)[['raion', 'lat', 'long']]
nans
# Out:
#                raion        lat        long
# 0  Kosino-Uhtomskoye  55.717061   37.863450
# 1      Obruchevskoye  55.660917   37.518479
# 2        Vojkovskoye  55.827247   37.497342
# 3   Beskudnikovskoye  55.873834   37.547836
# 4    Juzhnoportovoye  55.703916   37.702706
# 5       Savelovskoye  55.802750   37.587191
# 6  Losinoostrovskoye  55.826706   37.720950

# %%
# Porawione nany
wrong = pd.read_csv("../ext_data/wrong_dist.csv")
cl = wrong[wrong.columns[6]].str.split(",").apply(pd.Series)
cl = cl.rename(columns={0:"lat", 1:"long"})
wrong = wrong.join(cl)[['raion', 'lat', 'long']]
wrong
# Out:
#                    raion        lat        long
# 0         Tekstil'shhiki  55.708917   37.734371
# 1        Nizhegorodskoye  55.729628   37.723192
# 2             Sokol'niki  55.789198   37.679700
# 3                Mar'ino  55.549093   37.322844
# 4              Nagornoye  56.070112   38.022317
# 5              Otradnoye  55.863207   37.604762
# 6           Bogorodskoye  55.804182   37.684164
# 7               Ljublino  55.675682   37.761770
# 8           Danilovskoye  55.709217   37.640596
# 9               Donskoye  55.697529   37.617411
# 10                 Sokol  55.804805   37.515461
# 11               Kurkino  55.891239   37.389661
# 12             Izmajlovo  55.788409   37.743031
# 13            Taganskoye  55.739747   37.664231
# 14       Timirjazevskoye  55.820920   37.560260
# 15            Rjazanskij  55.719409   37.780904
# 16             Ajeroport  55.803089   37.542484
# 17       Akademicheskoye  55.687761   37.573447
# 18              Shhukino  55.800590   37.473519
# ...

# %%
base = base.rename(columns={"longitude": "lat", "latitude": "long"})

# %%
base = base.fillna(0)
base = base[abs(base['lat'] - LAT) < 1 & (base['long'] != 0)][['raion', 'lat', 'long']]
#base

# %%
final = base.append(nans).append(wrong)
#final

# %%
def reverse(string):
    if string.endswith("oye"):
        return string[:-3]+"oe"
    else:
        return string
#final.to_csv("../ext_data/loc3.csv")

# %%
final.raion = final.raion.apply(reverse)
final = final.drop_duplicates(['raion'])

# %%
#pd.read_csv("../ext_data/loc2.csv")

# %%
#final.lat = final.lat.apply(float)
#final.long = final.long.apply(float)
#final

# %%
set(final.raion.tolist()).difference(set(raions))
# Out:
# set()

# %%
r1 = set(raions)

# %%
r2 = set(final.raion.tolist())

# %%
r1.difference(r2)
# Out:
# {'Presnenskoe', 'Solncevo'}

# %%
# Ostatnie poprawki
df = pd.read_csv("../ext_data/loc3.csv")
df.raion = df.raion.apply(reverse)
df = df.drop_duplicates(['raion'])

# %%
df.to_csv("../ext_data/loc4.csv")

# %%
df
# Out:
#      Unnamed: 0                   raion                 lat       long
# 0           0.0                Bibirevo           55.894879  37.607745
# 1           1.0       Nagatinskij Zaton           55.685274  37.700658
# 2           3.0                  Mitino  55.845369999999996  37.365828
# 3           4.0               Basmannoe           55.104476  37.749894
# 4           7.0                 Koptevo           55.832515  37.529043
# 5           8.0                 Kuncevo            55.74261  37.398482
# 6          10.0       Zapadnoe Degunino  55.872339000000004  37.519162
# 7          12.0               Lefortovo  55.753634999999996  37.704817
# 8          14.0               Kuz'minki  55.698640000000005  37.773547
# 9          15.0                Nagornoe  55.903302000000004  37.629628
# 10         16.0              Gol'janovo           55.824162  37.796130
# 11         17.0                 Vnukovo           55.608475  37.292400
# ...
